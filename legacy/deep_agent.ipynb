# %%
import click
from deepagents import create_deep_agent
from langchain_core.tools import tool
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage , BaseMessage
from typing import List
import os

# %%
gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
gemini_api_key
# Out:
# 'AIzaSyCTma9ZZe6LG41K8xwMQA6r0Zz8AMRzhCs'

# %%
llm = ChatGoogleGenerativeAI(
    model='gemini-2.5-flash',
    api_key = gemini_api_key,
    temperature=0,

)

# %%
response = llm.invoke("say hello")

# %%
response.content
# Out:
# 'Hello!'

# %%
# ll, wrapper defination 
#mcp server setup 
#persistent memory 
#websocket configuration anf feetching subagents 
#algorthim ana;yzer sgent a
#agent to execute trade on zeroda applixatio through rest api

# %%
## llm  reusable wrapper function 
@dataclass
class LLMConfig:
    model : str
    api_key : str
    temperature : float = 0.0
    max_token : int = 1024 

class LLMService:
    def __init__(self , config : LLMConfig):
        self.llm = ChatGooglrGenerativeAI(
            model = config.model,
            api_key = config.api_key,
            tempratue = config.tempratue
        )
